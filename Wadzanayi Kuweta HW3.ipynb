# %%
import datetime
import pandas_datareader as pdr
import pandas as pd

api_key='1b5ea87e3498bf53fe93e50d2a7966882afa2da1'


tickers = ['TSLA', 'GM', 'TM','NIO']


start="2020-1-1"
end="2021-7-1"

df = pdr.tiingo.TiingoDailyReader(tickers, start=start, end=end, api_key=api_key)


all_data = df.read()
all_data
# Out:
# C:\Users\Wkuwe\anaconda3\lib\site-packages\pandas_datareader\tiingo.py:234: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   return pd.concat(dfs, self._concat_axis)
#                                    close      high       low    open  \
# symbol date
# TSLA   2020-01-02 00:00:00+00:00  430.26  430.7000  421.7100  424.50
#        2020-01-03 00:00:00+00:00  443.01  454.0000  436.9200  440.50
#        2020-01-06 00:00:00+00:00  451.54  451.5600  440.0000  440.47
#        2020-01-07 00:00:00+00:00  469.06  471.6300  453.3600  461.40
#        2020-01-08 00:00:00+00:00  492.14  498.4900  468.2300  473.70
# ...                                  ...       ...       ...     ...
# NIO    2021-06-25 00:00:00+00:00   45.07   45.9400   44.8800   45.78
#        2021-06-28 00:00:00+00:00   49.40   49.6500   45.5501   45.72
#        2021-06-29 00:00:00+00:00   50.34   50.6100   48.5500   49.15
# ...

# %%
# Import matplotlib
import matplotlib.pyplot as plt 

# Isolate the `Adj Close` values and transform the DataFrame
daily_close_px = all_data[['adjClose']].reset_index().pivot('date', 'symbol', 'adjClose')

# Calculate the daily percentage change for `daily_close_px`
daily_pct_change = daily_close_px.pct_change()

# Plot the distributions
daily_pct_change.hist(bins=50, sharex=True, figsize=(12,8))

# Show the resulting plot
plt.show()

# %%
#•	For my analysis, I chose 2 Legacy (Toyota Motors and General Motors) car manufacturers and 2 Electric Vehicle (Tesla and Nio) manufacturers.

# •	The peaks for all the stocks are at zero for TM and GM meaning the percentage change in price has remained constant more frequently, especially for GM
# •	For the electric vehicle manufacturers, the peaks are on a negative scale, meaning the stocks have experienced negative changes in prices more frequently than the traditional car manufacturers.
# •	The data distribution is asymmetrical and follows a normal distribution. Most of the data is clustered around the zero-percentage change for traditional car manufacturers and just below zero for EV manufacturers.

# •	Despite people embracing green technology most people still view cars as less efficient than traditional cars hence the negative changes.

# •	The percentage spread is from 0.2 to -0.2, showing that all the stocks haven’t experienced much volatility.
# •	For all graphs, there are outliers but considering the spread, they are insignificant.

# •	The market is in love with the electric vehicle stocks as they’re performing approximately up to par with the traditional car manufacturers. This performance shows that the clean energy transition is real
